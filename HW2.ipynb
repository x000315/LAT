# %%
import pandas as pd

df = pd.read_csv('opendata109m113.csv')

df
# Out:
#        site_id marriage_type  sex nation     edu     age  marry_count
# 0       新北市板橋區          不同性別    男     本國    博士畢業   未滿15歲            0
# 1       新北市板橋區          不同性別    男     本國    博士畢業  15～19歲            0
# 2       新北市板橋區          不同性別    男     本國    博士畢業  20～24歲            0
# 3       新北市板橋區          不同性別    男     本國    博士畢業  25～29歲            0
# 4       新北市板橋區          不同性別    男     本國    博士畢業  30～34歲            7
# ...        ...           ...  ...    ...     ...     ...          ...
# 618235  連江縣東引鄉          相同性別    女   其他地區  國小畢業以下  45～49歲            0
# 618236  連江縣東引鄉          相同性別    女   其他地區  國小畢業以下  50～54歲            0
# 618237  連江縣東引鄉          相同性別    女   其他地區  國小畢業以下  55～59歲            0
# 618238  連江縣東引鄉          相同性別    女   其他地區  國小畢業以下  60～64歲            0
# 618239  連江縣東引鄉          相同性別    女   其他地區  國小畢業以下   65歲以上            0
#
# [618240 rows x 7 columns]
